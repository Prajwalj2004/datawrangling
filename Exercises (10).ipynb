# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime=pd.read_csv(url)
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime['Year']=pd.to_datetime(crime['Year'])
crime.dtypes
# Out:
# Year                  datetime64[ns]
# Population                     int64
# Total                          int64
# Violent                        int64
# Property                       int64
# Murder                         int64
# Forcible_Rape                  int64
# Robbery                        int64
# Aggravated_assault             int64
# Burglary                       int64
# Larceny_Theft                  int64
# Vehicle_Theft                  int64
# dtype: object

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime.set_index('Year')
crime.head()
# Out:
#                            Year  Population    Total  Violent  Property  \
# 0 1970-01-01 00:00:00.000001960   179323175  3384200   288460   3095700
# 1 1970-01-01 00:00:00.000001961   182992000  3488000   289390   3198600
# 2 1970-01-01 00:00:00.000001962   185771000  3752200   301510   3450700
# 3 1970-01-01 00:00:00.000001963   188483000  4109500   316970   3792500
# 4 1970-01-01 00:00:00.000001964   191141000  4564600   364220   4200400
#
#    Murder  Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# 0    9110          17190   107840              154320    912100
# 1    8740          17220   106670              156760    949600
# 2    8530          17550   110860              164570    994300
# 3    8640          17650   116470              174210   1086400
# 4    9360          21420   130390              203050   1213200
#
#    Larceny_Theft  Vehicle_Theft
# 0        1855400         328200
# 1        1913000         336000
# 2        2089600         366800
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime.drop(columns=['Total'])
crime.head()
# Out:
#                            Year  Population    Total  Violent  Property  \
# 0 1970-01-01 00:00:00.000001960   179323175  3384200   288460   3095700
# 1 1970-01-01 00:00:00.000001961   182992000  3488000   289390   3198600
# 2 1970-01-01 00:00:00.000001962   185771000  3752200   301510   3450700
# 3 1970-01-01 00:00:00.000001963   188483000  4109500   316970   3792500
# 4 1970-01-01 00:00:00.000001964   191141000  4564600   364220   4200400
#
#    Murder  Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# 0    9110          17190   107840              154320    912100
# 1    8740          17220   106670              156760    949600
# 2    8530          17550   110860              164570    994300
# 3    8640          17650   116470              174210   1086400
# 4    9360          21420   130390              203050   1213200
#
#    Larceny_Theft  Vehicle_Theft
# 0        1855400         328200
# 1        1913000         336000
# 2        2089600         366800
# ...

# %%
crime.tail()
# Out:
#                             Year  Population     Total  Violent  Property  \
# 50 1970-01-01 00:00:00.000002010   309330219  10363873  1251248   9112625
# 51 1970-01-01 00:00:00.000002011   311587816  10258774  1206031   9052743
# 52 1970-01-01 00:00:00.000002012   313873685  10219059  1217067   9001992
# 53 1970-01-01 00:00:00.000002013   316497531   9850445  1199684   8650761
# 54 1970-01-01 00:00:00.000002014   318857056   9475816  1197987   8277829
#
#     Murder  Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# 50   14772          85593   369089              781844   2168457
# 51   14661          84175   354772              752423   2185140
# 52   14866          85141   355051              762009   2109932
# 53   14319          82109   345095              726575   1931835
# 54   14249          84041   325802              741291   1729806
#
#     Larceny_Theft  Vehicle_Theft
# 50        6204601         739565
# 51        6151095         716508
# ...

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
crime['year']=crime['Year'].dt.year
crime.head()
# Out:
#                            Year  Population    Total  Violent  Property  \
# 0 1970-01-01 00:00:00.000001960   179323175  3384200   288460   3095700
# 1 1970-01-01 00:00:00.000001961   182992000  3488000   289390   3198600
# 2 1970-01-01 00:00:00.000001962   185771000  3752200   301510   3450700
# 3 1970-01-01 00:00:00.000001963   188483000  4109500   316970   3792500
# 4 1970-01-01 00:00:00.000001964   191141000  4564600   364220   4200400
#
#    Murder  Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# 0    9110          17190   107840              154320    912100
# 1    8740          17220   106670              156760    949600
# 2    8530          17550   110860              164570    994300
# 3    8640          17650   116470              174210   1086400
# 4    9360          21420   130390              203050   1213200
#
#    Larceny_Theft  Vehicle_Theft  year
# 0        1855400         328200  1970
# 1        1913000         336000  1970
# ...

# %%
def decades(x):
        if x>=1970 and x<=1980:
            return "grouped 1970-80"

# %%
crime['decades']=crime['year'].apply(decades)
crime.head()
# Out:
#                            Year  Population    Total  Violent  Property  \
# 0 1970-01-01 00:00:00.000001960   179323175  3384200   288460   3095700
# 1 1970-01-01 00:00:00.000001961   182992000  3488000   289390   3198600
# 2 1970-01-01 00:00:00.000001962   185771000  3752200   301510   3450700
# 3 1970-01-01 00:00:00.000001963   188483000  4109500   316970   3792500
# 4 1970-01-01 00:00:00.000001964   191141000  4564600   364220   4200400
#
#    Murder  Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# 0    9110          17190   107840              154320    912100
# 1    8740          17220   106670              156760    949600
# 2    8530          17550   110860              164570    994300
# 3    8640          17650   116470              174210   1086400
# 4    9360          21420   130390              203050   1213200
#
#    Larceny_Theft  Vehicle_Theft  year          decades
# 0        1855400         328200  1970  grouped 1970-80
# ...

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
crime.drop(columns='Year').groupby(['decades']).sum()
# Out:
#                   Population      Total   Violent   Property  Murder  \
# decades
# grouped 1970-80  13538557224  583173026  65384309  517687418  952448
#
#                  Forcible_Rape   Robbery  Aggravated_assault   Burglary  \
# decades
# grouped 1970-80        3999314  22904744            37464999  133320955
#
#                  Larceny_Theft  Vehicle_Theft    year
# decades
# grouped 1970-80      327797108       56573743  108350

# %%
#Step 9:

crime.groupby(['decades'])['Total'].max()
# Out:
# decades
# grouped 1970-80    14872900
# Name: Total, dtype: int64
