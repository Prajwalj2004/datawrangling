# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %%
url='https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine=pd.read_csv(url)
wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
wine.shape
# Out:
# (177, 14)

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine=wine.drop(columns=['1','2.43','2.8','.28','5.64','3.92','1065'])
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
dict1={'14.23':'alcohol','1.71':'malic_acid','15.6':'alcalinity_of_ash','127':'magnesium','3.06':'flavanoids','2.29':'proanthocyanins','1.04':'hue'}
wine=wine.rename(columns=dict1)
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.20        1.78               11.2        100        2.76
# 1      13.16        2.36               18.6        101        3.24
# 2      14.37        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.loc[:2,'alcohol']=np.NaN
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[2:4,'magnesium']=np.NaN
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
wine.dtypes
# Out:
# alcohol              float64
# malic_acid           float64
# alcalinity_of_ash    float64
# magnesium            float64
# flavanoids           float64
# proanthocyanins      float64
# hue                  float64
# dtype: object

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine['alcohol']=wine['alcohol'].fillna(10)
wine['magnesium']=wine['magnesium'].fillna(100)
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1      10.00        2.36               18.6      101.0        3.24
# 2      10.00        1.95               16.8      100.0        3.49
# 3      13.24        2.59               21.0      100.0        2.69
# 4      14.20        1.76               15.2      100.0        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
arr=np.random.randint(0,10,10)
arr
# Out:
# array([1, 3, 1, 6, 0, 3, 1, 4, 7, 8])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.iloc[arr]=np.NaN
wine.iloc[arr]
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 1      NaN         NaN                NaN        NaN         NaN
# 3      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 6      NaN         NaN                NaN        NaN         NaN
# 0      NaN         NaN                NaN        NaN         NaN
# 3      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 4      NaN         NaN                NaN        NaN         NaN
# 7      NaN         NaN                NaN        NaN         NaN
# 8      NaN         NaN                NaN        NaN         NaN
#
#    proanthocyanins  hue
# 1              NaN  NaN
# 3              NaN  NaN
# 1              NaN  NaN
# 6              NaN  NaN
# 0              NaN  NaN
# 3              NaN  NaN
# 1              NaN  NaN
# 4              NaN  NaN
# ...

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isnull().sum()
# Out:
# alcohol              7
# malic_acid           7
# alcalinity_of_ash    7
# magnesium            7
# flavanoids           7
# proanthocyanins      7
# hue                  7
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine=wine.dropna() #function to drop all the null values in the row #drop function deletes columns

# %%
wine.shape
# Out:
# (170, 7)

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 2      10.00        1.95               16.8      100.0        3.49
# 5      14.39        1.87               14.6       96.0        2.52
# 9      14.10        2.16               18.0      105.0        3.32
# 10     14.12        1.48               16.8       95.0        2.43
# 11     13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 2               2.18  0.86
# 5               1.98  1.02
# 9               2.38  1.25
# 10              1.57  1.17
# ...

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine=wine.reset_index()
wine.head()
# Out:
#    index  alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      2    10.00        1.95               16.8      100.0        3.49
# 1      5    14.39        1.87               14.6       96.0        2.52
# 2      9    14.10        2.16               18.0      105.0        3.32
# 3     10    14.12        1.48               16.8       95.0        2.43
# 4     11    13.75        1.73               16.0       89.0        2.76
#
#    proanthocyanins   hue
# 0             2.18  0.86
# 1             1.98  1.02
# 2             2.38  1.25
# 3             1.57  1.17
# 4             1.81  1.15

# %%
wine=wine.drop(columns=['level_0','index'])
wine.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 wine=wine.drop(columns=['level_0','index'])
#       2 wine.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
